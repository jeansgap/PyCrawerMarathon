# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

#下載檔案
import requests

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

print (response)

#根據回傳內容一次回傳30筆資料
#
# Out:
# [{"id":235455201,"title":"讓我成為妳的一輩子","excerpt":"前陣子到中途貓舍想領養隻浪浪回家，沒想到一連串的「被審理」後，還是被拒絕了，正當心灰意冷時 妳來到了我的身邊，從來沒想過會養到隻長毛貓，還是夢寐以求的布偶🥺🥺，作為一個養貓新手真的好緊張爬了一堆文","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2021-03-01T13:11:19.890Z","updatedAt":"2021-03-01T13:11:19.890Z","commentCount":16,"likeCount":161,"withNickname":false,"tags":[],"topics":["寵物","貓","布偶貓","新手"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"F","school":"國立高雄海洋科技大學","replyTitle":null,"mediaMeta":[{"id":"ef61f939-e5f3-40aa-8915-e7e9456afca0","url":"https://i.imgur.com/VapJw4ul.jpg","normalizedUrl":"https://i.imgur.com/VapJw4ul.jpg","thumbnail":"https://i.imgur.com/VapJw4ul.jpg","type":"image/thumbnail","tags":[],"createdAt":"2021-03-01T13:11:19.890Z","updatedAt":"2021-03-01T13:11:19.890Z","width":1500,"height":2000},{"id":"ef61f939-e5f3-40aa-8915-e7e9456afca0","url":"https://i.imgur.com/VapJw4u.jpg","normalizedUrl":"https://imgur.com/VapJw4u","thumbnail":"https://i.imgur.com/VapJw4ul.jpg","type":"image/imgur","tags":[],"createdAt":"2021-03-01T13:11:19.890Z","updatedAt":"2021-03-01T13:11:19.890Z","width":1500,"height":2000},{"id":"e284bd20-b76c-4130-81ff-ade2b59f4bb2","url":"https://i.imgur.com/oqPpumN.jpg","normalizedUrl":"https://imgur.com/oqPpumN","thumbnail":"https://i.imgur.com/oqPpumNl.jpg","type":"image/imgur","tags":[],"createdAt":"2021-03-01T13:11:19.890Z","updatedAt":"2021-03-01T13:11:19.890Z","width":1500,"height":2000}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":161}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"isModerator":false,"layout":"classic","spoilerAlert":false,"withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/VapJw4u.jpg"},{"url":"https://i.imgur.com/oqPpumN.jpg"}],"reportReasonText":"","excerptComments":[],"postAvatar":"","verifiedBadge":false},{"id":235453387,"title":"🐱🐶特寵業者爭議名單彙整","excerpt":"會想發這篇文，是因為發現有人會在板上的挑選文下面推薦一些很明顯不OK的業者，再加上有時反推文會用截圖或暗示的方式讓人做功課時搜尋不易，所以我把一些糾紛文整理起來，希望能讓大家多多利用，先說說我整理過後","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2021-03-01T08:28:42.248Z","updatedAt":"2021-03-02T10:43:27.509Z","commentCount":11,"likeCount":67,"withNickname":false,"tags":[],"topics":["寵物店","貓舍","犬舍","寵物"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","nsfw":false,"gender":"F","school":"國立屏東科技大學","replyTitle":null,"mediaMeta":[{"id":"6cd4ce4d-0ff9-43ee-8e3b-77c81993ed7d","url":"https://i.imgur.com/0jbJBKBl.jpg","normalizedUrl":"https://i.imgur.com/0jbJBKBl.jpg","thumbnail":"https://i.imgur.com/0jbJBKBl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2021-03-01T08:28:42.248Z","updatedAt":"2021-03-02T10:43:27.509Z","width":1080,"height":2054,"croppingWindow":{"anchorX":0,"anchorY":216,"width":1080,"height":648}},{"id":"6cd4ce4d-0ff9-43ee-8e3b-77c81993ed7d","url":"https://i.imgur.com/0jbJBKB.jpg","normalizedUrl":"https://imgur.com/0jbJBKB","thumbnail":"https://i.imgur.com/0jbJBKBl.jpg","type":"image/imgur","tags":["ANNOTATED"],"createdAt":"2021-03-01T08:28:42.248Z","updatedAt":"2021-03-02T10:43:27.509Z","width":1080,"height":2054,"croppingWindow":{"anchorX":0,"anchorY":216,"width":1080,"height":648}}],"reactions":[{"id":"286f599c-f86a-4932-82f0-f5a06f1eca03","count":67}],"hidden":false,"customStyle":null,"isSuspiciousAccount":false,"isModerator":false,"layout":"classic","spoilerAlert":false,"withImages":true,"withVideos":false,"media":[{"url":"https://i.imgur.com/0jbJBKB.jpg"}],"reportReasonText":"","excerptComments":[],"postAvatar":"","verifiedBadge":false},{"id":235455290,"title":"瞞著家人去工作？","excerpt":"有天家裡群組跳通知：欸努努是不是自己偷偷去當日雜麻豆？然後傳了這張照片 給我們🤣！（上圖），當下看到覺得有像！，！過年的時候還發了紅包給他🧧，是說會自己賺錢..還敢跟我們拿紅包啊！ಠ_ಠ，拿了紅包還臭","anonymousSchool":false,"anonymousDepartment":true,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"cre ...
# 讓我成為妳的一輩子
# 🐱🐶特寵業者爭議名單彙整
# 瞞著家人去工作？
# 請問貓咪和貓咪的相處模式？
# 請問有人知道小雞怎麼了嗎😭
# 貓只吃乾乾
# #貓 擄獲媽媽的心
# 我家小狗沒藥救了
# 天竺鼠車車退流行啦！
# （提問）幼貓睡覺問題
# 最狂送養文🤣
# 轉換新外出包貓咪一直吐？
# 天竺鼠疾病分享—血尿
# 領養貓貓
# 如果有人願意愛牠們❤️
# 台中市勤美3/1下午4:00 英短走失！
# 貓咪傳染性腹膜炎會自然好嗎？
# 打狗？打小孩？多管閒事？
# 愛鑽衣櫃臭貓
# 烏龜是不是生病了🤔？
# 貓咪過敏
# 各種奇怪的睡姿
# 會開窗戶七逃的貓
# #黑特 台南中西區惡劣寵物美容店
# 跟自己的狗都說什麼
# 寵物上學經驗求助
# 養的水草突然長的很高
# #詢問貓咪掉毛
# 離開房間就一直叫😢
# 就是想曬曬貓🥰 #有圖

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

import json

data = json.loads(response)

for d in data:
    print(d['title'])
# Out:
# '\nYour Code\n'

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

'''
Your Code
'''
# Out:
# '\nYour Code\n'
